# %%
# import required libraries
import numpy as np
import pandas as pd
from skimage import io, transform
import cv2

# %%
# load and read an image
image = io.imread(r"C:\Users\Administrator\Desktop\Brain_MRI_Tumor_Detection\brain_tumor_dataset\yes\Y14.jpg")
image
# Out:
# array([[ 12,  15,  19, ...,  73,  73,  65],
#        [ 12,  15,  19, ...,  94,  94,  98],
#        [ 12,  14,  18, ...,  15,  15,  14],
#        ...,
#        [ 20,  20,  20, ...,  54, 181,  88],
#        [ 15,  15,  14, ..., 157, 117,  21],
#        [ 70,  70,  68, ..., 184,  30,  30]], dtype=uint8)

# %%
# shape of image array
image.shape
# Out:
# (300, 289)

# %%
# type of image
type(image)
# Out:
# numpy.ndarray

# %%
# show image
io.imshow(image)

# %%
# resize image
resize_image = transform.resize(image, (100, 100))
io.imshow(resize_image)

# %%
img = cv2.imread(r'C:\Users\Administrator\Desktop\Brain_MRI_Tumor_Detection\brain_tumor_dataset\yes\Y14.jpg')
cv2.imshow('image', img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import matplotlib.pyplot as plt
plt.imshow(img)

# %%
# resize image using opencv
resize = cv2.resize(img, (70, 70))
plt.imshow(resize)

# %%
img.shape
# Out:
# (300, 289, 3)

# %%
# reshape image
reshape = img.reshape(-1)
reshape.shape
# Out:
# (260100,)

# %%
img.shape
# Out:
# (300, 289, 3)

# %%
reshape1 = img.reshape(1, -1)
reshape1.shape
# Out:
# (1, 260100)

# %%
reshape2 = img.reshape(-1, 1)
reshape2.shape
# Out:
# (260100, 1)

# %%
img1 = img - 100
plt.imshow(img1)

# %%
img
# Out:
# array([[[ 12,  12,  12],
#         [ 15,  15,  15],
#         [ 19,  19,  19],
#         ...,
#         [ 73,  73,  73],
#         [ 73,  73,  73],
#         [ 65,  65,  65]],
#
#        [[ 12,  12,  12],
#         [ 15,  15,  15],
#         [ 19,  19,  19],
#         ...,
#         [ 94,  94,  94],
#         [ 94,  94,  94],
#         [ 98,  98,  98]],
#
#        [[ 12,  12,  12],
#         [ 14,  14,  14],
#         [ 18,  18,  18],
#         ...,
#         [ 15,  15,  15],
#         [ 15,  15,  15],
#         [ 14,  14,  14]],
#
#        ...,
#
#        [[ 20,  20,  20],
#         [ 20,  20,  20],
#         [ 20,  20,  20],
#         ...,
#         [ 54,  54,  54],
#         [181, 181, 181],
#         [ 88,  88,  88]],
#
#        [[ 15,  15,  15],
#         [ 15,  15,  15],
#         [ 14,  14,  14],
#         ...,
#         [157, 157, 157],
#         [117, 117, 117],
#         [ 21,  21,  21]],
#
#        [[ 70,  70,  70],
#         [ 70,  70,  70],
#         [ 68,  68,  68],
# ...

# %%
matrix1 = [[20, 2, 10, 30], 
           [2, 20, 2, 10], 
           [10, 2, 20, 2], 
           [30, 10, 2, 20]]
plt.imshow(matrix1)

# %%
plt.imshow(img)

# %%
# crop an image

# top left corner index in an image
(x, y) = (80, 50)

width, height = 250, 300

cropped_image = img[x : x + width, y : y + height]
plt.imshow(cropped_image)

# %%
# flipping an image

# flip an image in horizontal direction
hori_flip = cv2.flip(img, 1)
plt.imshow(hori_flip)

# %%
# flio in both directions
flipp = cv2.flip(img, -1)
plt.imshow(flipp)
